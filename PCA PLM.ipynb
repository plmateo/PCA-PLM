# %%
from google.colab import drive
drive.mount('content/')
# Out:
# Mounted at content/

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from scipy.stats import pearsonr
from sklearn.cluster import KMeans

# %%
df = pd.read_csv('/content/content/MyDrive/0 Colab Notebooks/Machine learning/DATASETS/Mall_Customers.csv')
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %%
df = df.drop(['Gender'], axis=1)
df = df.drop(['CustomerID'], axis=1)

df
# Out:
#      Age  Annual Income (k$)  Spending Score (1-100)
# 0     19                  15                      39
# 1     21                  15                      81
# 2     20                  16                       6
# 3     23                  16                      77
# 4     31                  17                      40
# ..   ...                 ...                     ...
# 195   35                 120                      79
# 196   45                 126                      28
# 197   32                 126                      74
# 198   32                 137                      18
# 199   30                 137                      83
#
# [200 rows x 3 columns]

# %%
plt.scatter(df['Age'], df['Annual Income (k$)'])
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.show()

# %%
df = np.array(df)
df
# Out:
# array([[ 19,  15,  39],
#        [ 21,  15,  81],
#        [ 20,  16,   6],
#        [ 23,  16,  77],
#        [ 31,  17,  40],
#        [ 22,  17,  76],
#        [ 35,  18,   6],
#        [ 23,  18,  94],
#        [ 64,  19,   3],
#        [ 30,  19,  72],
#        [ 67,  19,  14],
#        [ 35,  19,  99],
#        [ 58,  20,  15],
#        [ 24,  20,  77],
#        [ 37,  20,  13],
#        [ 22,  20,  79],
#        [ 35,  21,  35],
#        [ 20,  21,  66],
#        [ 52,  23,  29],
#        [ 35,  23,  98],
#        [ 35,  24,  35],
#        [ 25,  24,  73],
#        [ 46,  25,   5],
#        [ 31,  25,  73],
#        [ 54,  28,  14],
#        [ 29,  28,  82],
#        [ 45,  28,  32],
#        [ 35,  28,  61],
#        [ 40,  29,  31],
#        [ 23,  29,  87],
#        [ 60,  30,   4],
#        [ 21,  30,  73],
#        [ 53,  33,   4],
#        [ 18,  33,  92],
#        [ 49,  33,  14],
#        [ 21,  33,  81],
#        [ 42,  34,  17],
#        [ 30,  34,  73],
# ...

# %%
# Perform the necessary imports
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler




# Assign the 0th column of grains: width
x = df[:,0]

# Assign the 1st column of grains: length
y = df[:,1]

# Scatter plot width vs length
plt.scatter(x, y)
plt.xlabel('Age')
plt.ylabel('Annual Income (k$)')
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation
correlation, pvalue = pearsonr(x, y)

# Display the correlation
print(correlation)
# Out:
# -0.012398042736060159

# %%
scaler = StandardScaler()
df = scaler.fit_transform(df)


# Create PCA instance: model
model = PCA()

# Apply the fit_transform method of model to grains: pca_features
pca_features = model.fit_transform(df)

# Assign 0th column of pca_features: xs
xs = pca_features[:,0]

# Assign 1st column of pca_features: ys
ys = pca_features[:,1]

# Scatter plot xs vs ys
plt.scatter(xs, ys)
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation of xs and ys
correlation, pvalue = pearsonr(xs, ys)

# Display the correlation
print("Display the correlation: ",correlation)
# Out:
# Display the correlation:  -1.8735013540549517e-16

# %%
# Create PCA instance: model
model = PCA()

# Apply the fit_transform method of model to grains: pca_features
pca_features = model.fit_transform(df)

# Assign 0th column of pca_features: xs
xs = pca_features[:,0]

# Assign 1st column of pca_features: ys
ys = pca_features[:,2]

# Scatter plot xs vs ys
plt.scatter(xs, ys)
plt.axis('equal')
plt.show()

# Calculate the Pearson correlation of xs and ys
correlation, pvalue = pearsonr(xs, ys)

# Display the correlation
print("Display the correlation: ",correlation)
# Out:
# Display the correlation:  -3.5908775952719907e-16

# %%
# Make a scatter plot of the untransformed points
plt.scatter(df[:,0], df[:,2])

# Create a PCA instance: model
model = PCA()

# Fit model to points
model.fit(df)

# Get the mean of the grain samples: mean
mean = model.mean_

# Get the first principal component: first_pc
first_pc = model.components_[0,:]

# Plot first_pc as an arrow, starting at mean
plt.arrow(mean[0], mean[2], first_pc[0], first_pc[2], color='red', width= 0.07)

# Keep axes on same scale
plt.axis('equal')
plt.show()

# %%
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'samples'
pipeline.fit(df)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %%
df
# Out:
# array([[ 19,  15,  39],
#        [ 21,  15,  81],
#        [ 20,  16,   6],
#        [ 23,  16,  77],
#        [ 31,  17,  40],
#        [ 22,  17,  76],
#        [ 35,  18,   6],
#        [ 23,  18,  94],
#        [ 64,  19,   3],
#        [ 30,  19,  72],
#        [ 67,  19,  14],
#        [ 35,  19,  99],
#        [ 58,  20,  15],
#        [ 24,  20,  77],
#        [ 37,  20,  13],
#        [ 22,  20,  79],
#        [ 35,  21,  35],
#        [ 20,  21,  66],
#        [ 52,  23,  29],
#        [ 35,  23,  98],
#        [ 35,  24,  35],
#        [ 25,  24,  73],
#        [ 46,  25,   5],
#        [ 31,  25,  73],
#        [ 54,  28,  14],
#        [ 29,  28,  82],
#        [ 45,  28,  32],
#        [ 35,  28,  61],
#        [ 40,  29,  31],
#        [ 23,  29,  87],
#        [ 60,  30,   4],
#        [ 21,  30,  73],
#        [ 53,  33,   4],
#        [ 18,  33,  92],
#        [ 49,  33,  14],
#        [ 21,  33,  81],
#        [ 42,  34,  17],
#        [ 30,  34,  73],
# ...

# %%
model.components_
# Out:
# array([[-0.1889742 ,  0.58864102,  0.7859965 ],
#        [ 0.1309652 ,  0.80837573, -0.57391358],
#        [ 0.97320957,  0.00551667,  0.22985365]])

# %%
mean
# Out:
# array([38.85, 60.56, 50.2 ])

# %%
df.info()

# %%
samples = pd.read_csv('https://assets.datacamp.com/production/repositories/655/datasets/fee715f8cf2e7aad9308462fea5a26b791eb96c4/fish.csv')
samples.drop(columns=['Bream'], inplace=True)

# %%
# Perform the necessary imports
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
import matplotlib.pyplot as plt


# Create scaler: scaler
scaler = StandardScaler()

# Create a PCA instance: pca
pca = PCA()

# Create pipeline: pipeline
pipeline = make_pipeline(scaler,pca)

# Fit the pipeline to 'samples'
pipeline.fit(samples)

# Plot the explained variances
features = range(pca.n_components_)
plt.bar(features, pca.explained_variance_)
plt.xlabel('PCA feature')
plt.ylabel('variance')
plt.xticks(features)
plt.show()

# %%
# Create a PCA model with 2 components: pca
pca = PCA(n_components=2)

scaled_samples = scaler.fit_transform(samples)
# Fit the PCA instance to the scaled samples
pca.fit(scaled_samples)

# Transform the scaled samples: pca_features
pca_features = pca.transform(scaled_samples)

# Print the shape of pca_features
print(pca_features.shape)
# Out:
# (84, 2)
